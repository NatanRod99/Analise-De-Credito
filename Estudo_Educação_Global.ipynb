# %% [markdown]
# <a href="https://colab.research.google.com/github/NatanRod99/Analise-De-Credito/blob/main/Estudo_Educa%C3%A7%C3%A3o_Global.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Try reading the CSV with a different encoding
df = pd.read_csv('/content/Global_Education.csv', encoding='latin-1')
print(df.head())  # Display the first few rows of the DataFrame

# %%
df.head()
# Out:
#   Countries and areas  Latitude   Longitude  OOSR_Pre0Primary_Age_Male  \
# 0         Afghanistan  33.939110  67.709953                          0
# 1             Albania  41.153332  20.168331                          4
# 2             Algeria  28.033886   1.659626                          0
# 3             Andorra  42.506285   1.521801                          0
# 4              Angola  11.202692  17.873887                         31
#
#    OOSR_Pre0Primary_Age_Female  OOSR_Primary_Age_Male  \
# 0                            0                      0
# 1                            2                      6
# 2                            0                      0
# 3                            0                      0
# 4                           39                      0
#
#    OOSR_Primary_Age_Female  OOSR_Lower_Secondary_Age_Male  \
# 0                        0                              0
# 1                        3                              6
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
renomear_colunas = {
    'Countries and areas': 'Países e áreas',
    'Latitude': 'Latitude',
    'Longitude': 'Longitude',
    'OOSR_Pre0Primary_Age_Male': 'Taxa de crianças fora da escola, pré-primário, masculino',
    'OOSR_Pre0Primary_Age_Female': 'Taxa de crianças fora da escola, pré-primário, feminino',
    'OOSR_Primary_Age_Male': 'Taxa de crianças fora da escola, primário, masculino',
    'OOSR_Primary_Age_Female': 'Taxa de crianças fora da escola, primário, feminino',
    'OOSR_Lower_Secondary_Age_Male': 'Taxa de crianças fora da escola, ensino fundamental II, masculino',
    'OOSR_Lower_Secondary_Age_Female': 'Taxa de crianças fora da escola, ensino fundamental II, feminino',
    'OOSR_Upper_Secondary_Age_Male': 'Taxa de crianças fora da escola, ensino médio, masculino',
    'OOSR_Upper_Secondary_Age_Female': 'Taxa de crianças fora da escola, ensino médio, feminino',
    'Primary_End_Proficiency_Reading': 'Proficiência em leitura no final do ensino fundamental',
    'Primary_End_Proficiency_Math': 'Proficiência em matemática no final do ensino fundamental',
    'Lower_Secondary_End_Proficiency_Reading': 'Proficiência em leitura no final do ensino fundamental II',
    'Lower_Secondary_End_Proficiency_Math': 'Proficiência em matemática no final do ensino fundamental II',
    'Youth_15_24_Literacy_Rate_Male': 'Taxa de alfabetização de jovens de 15 a 24 anos, masculino',
    'Youth_15_24_Literacy_Rate_Female': 'Taxa de alfabetização de jovens de 15 a 24 anos, feminino',
    'Birth_Rate': 'Taxa de natalidade',
    'Gross_Primary_Education_Enrollment': 'Matrícula bruta no ensino fundamental',
    'Gross_Tertiary_Education_Enrollment': 'Matrícula bruta no ensino superior',
    'Unemployment_Rate': 'Taxa de desemprego'
}

df = df.rename(columns=renomear_colunas)

# %%
df.head(30)
# Out:
#             Países e áreas  Latitude    Longitude  \
# 0              Afghanistan  33.939110   67.709953
# 1                  Albania  41.153332   20.168331
# 2                  Algeria  28.033886    1.659626
# 3                  Andorra  42.506285    1.521801
# 4                   Angola  11.202692   17.873887
# 5                 Anguilla  18.220554   63.068615
# 6      Antigua and Barbuda  17.060816   61.796428
# 7                Argentina  38.416097   63.616672
# 8                  Armenia  40.069099   45.038189
# 9                Australia  25.274398  133.775136
# 10                 Austria  47.516231   14.550072
# 11              Azerbaijan  40.143105   47.576927
# 12             The Bahamas  25.034280   77.396280
# 13                 Bahrain  26.066700   50.557700
# 14              Bangladesh  23.684994   90.356331
# 15                Barbados  13.193887   59.543198
# 16                 Belarus  53.709807   27.953389
# 17                 Belgium  50.503887    4.469936
# ...

# %%
df.describe()
# Out:
#         Latitude    Longitude  \
# count  202.000000  202.000000
# mean    25.081422   55.166928
# std     16.813639   45.976287
# min      0.023559    0.824782
# 25%     11.685062   18.665678
# 50%     21.207861   43.518091
# 75%     39.901792   77.684945
# max     64.963051  178.065032
#
#        Taxa de crianças fora da escola, pré-primário, masculino  \
# count                                         202.000000
# mean                                           19.658416
# std                                            25.007604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             9.000000
# 75%                                            31.000000
# max                                            96.000000
#
#        Taxa de crianças fora da escola, pré-primário, feminino  \
# count                                         202.000000
# ...
